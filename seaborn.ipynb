# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline
plt.rcParams['figure.figsize'] = 6,2
import warnings
warnings.filterwarnings('ignore')

# %%
df = pd.read_csv(r'/Users/dilipreddy/Downloads/data.csv')

# %%
df
# Out:
#               CountryName CountryCode  BirthRate  InternetUsers  \
# 0                   Aruba         ABW     10.244           78.9
# 1             Afghanistan         AFG     35.253            5.9
# 2                  Angola         AGO     45.985           19.1
# 3                 Albania         ALB     12.877           57.2
# 4    United Arab Emirates         ARE     11.044           88.0
# ..                    ...         ...        ...            ...
# 190           Yemen, Rep.         YEM     32.947           20.0
# 191          South Africa         ZAF     20.850           46.5
# 192      Congo, Dem. Rep.         COD     42.394            2.2
# 193                Zambia         ZMB     40.471           15.4
# 194              Zimbabwe         ZWE     35.715           18.5
#
#              IncomeGroup  Unnamed: 5
# 0            High income    808.2516
# 1             Low income    207.9927
# 2    Upper middle income    878.3135
# 3    Upper middle income    736.5644
# ...

# %%
df["InternetUsers"]
# Out:
# 0      78.9
# 1       5.9
# 2      19.1
# 3      57.2
# 4      88.0
#        ...
# 190    20.0
# 191    46.5
# 192     2.2
# 193    15.4
# 194    18.5
# Name: InternetUsers, Length: 195, dtype: float64

# %%
vis = sns.distplot(df["InternetUsers"])
plt.show()

# %%
vis2 = sns.displot(df["InternetUsers"]) #univarent analysis
plt.show()

# %%
vis3 = sns.distplot(df["InternetUsers"],bins=10) #10 intervals 
plt.show()

# %%
vis4 =sns.boxplot(data= df,x="IncomeGroup",y="BirthRate")   #bi varient analysis
plt.show()

# %%
vis5 = sns.lmplot(data= df,x='InternetUsers',y='BirthRate')
plt.show()

# %%
vis6 =sns.lmplot(data= df,x="InternetUsers",y='BirthRate',fit_reg=False) #fit_reg =False no line
plt.show()                                                               #fig_reg =True line is visible

# %%
vis6 =sns.lmplot(data= df,x="InternetUsers",y='BirthRate',fit_reg=True, hue='IncomeGroup') #hue - Parameter is for color
plt.show()
